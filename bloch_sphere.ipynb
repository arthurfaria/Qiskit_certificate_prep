# %%
import numpy as np

from qiskit import QuantumCircuit, assemble, Aer, execute, BasicAer, QuantumRegister
from qiskit.visualization import plot_bloch_vector, plot_state_qsphere, plot_state_hinton, plot_bloch_multivector, plot_state_paulivec, plot_state_city
from qiskit.quantum_info import Statevector

from qiskit.tools.jupyter import *

# %%
#the mere plot_bloch_vector needs coordinate specifications

plot_bloch_vector([0.7,0.5,1]) #here for [x,y,z]; x=Tr[Xρ] and similar for y and z

# %%
plot_bloch_vector([1/np.sqrt(2),-1/np.sqrt(2),0])

# %%
## For separable states

ex_sep_state = QuantumCircuit(2)
ex_sep_state.h(0)
ex_sep_state.h(1)

ex_sv = Statevector.from_label("00")
ex_state = ex_sv.evolve(ex_sep_state)
plot_bloch_multivector(ex_state)
